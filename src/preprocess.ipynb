# %%
import pandas as pd

# %%
#Reading the txt file and naming the columns
Fertility_Diagnosis_set = pd.read_csv("../data/raw_fertility_Diagnosis.txt", header=None)

Fertility_Diagnosis_set.columns = ["Season", "Age", "Child Diseases", "Accident or Trauma", "Sirurgical Intervention", "High Fevers Last Year", "Frequency of Alcohool Comsumption", "Smoking Habit", "Numbers of Hours Sitting per Day", "Output"]

# %%
Fertility_Diagnosis_set
# Out:
#     Season   Age  Child Diseases  Accident or Trauma  Sirurgical Intervention  \
# 0    -0.33  0.69               0                   1                        1
# 1    -0.33  0.94               1                   0                        1
# 2    -0.33  0.50               1                   0                        0
# 3    -0.33  0.75               0                   1                        1
# 4    -0.33  0.67               1                   1                        0
# ..     ...   ...             ...                 ...                      ...
# 95   -1.00  0.67               1                   0                        0
# 96   -1.00  0.61               1                   0                        0
# 97   -1.00  0.67               1                   1                        1
# 98   -1.00  0.64               1                   0                        1
# 99   -1.00  0.69               0                   1                        1
#
#     High Fevers Last Year  Frequency of Alcohool Comsumption  Smoking Habit  \
# 0                       0                                0.8              0
# 1                       0                                0.8              1
# 2                       0                                1.0             -1
# 3                       0                                1.0             -1
# 4                       0                                0.8             -1
# ..                    ...                                ...            ...
# 95                      0                                1.0             -1
# 96                      0                                0.8              0
# 97                      0                                1.0             -1
# 98                      0                                1.0              0
# 99                      0                                0.6             -1
#
#     Numbers of Hours Sitting per Day Output
# 0                               0.88      N
# 1                               0.31      O
# 2                               0.50      N
# 3                               0.38      N
# 4                               0.50      O
# ..                               ...    ...
# 95                              0.50      N
# 96                              0.50      N
# 97                              0.31      N
# 98                              0.19      N
# 99                              0.19      N
#
# [100 rows x 10 columns]

# %%
#Replacing the numbers in season column by the actual names of the seasons
Fertility_Diagnosis_set["Season"] = Fertility_Diagnosis_set["Season"].replace({
    -0.33: "Spring",
    0.33: "Summer",
    1: "Autumn",
    -1: "Winter"
})

# %%
#Saving the new file
